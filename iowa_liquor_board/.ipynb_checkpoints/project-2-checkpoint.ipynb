# %% [markdown]
# # Getting started
#
# Once you've chosen your scenario, download the data from the Iowa website in csv format. Start by loading the data with pandas. You may need to parse the date columns appropriately.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb
import seaborn.linearmodels as sblm
import numpy as np
import seaborn as sb
import seaborn.linearmodels as sblm
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn import metrics
from sklearn.linear_model import LinearRegression

def eda(dataframe):
    print "Missing Values \n \n", dataframe.isnull().sum(),"\n"
    print "Duplicate Rows \n", dataframe.duplicated().sum(),"\n"
    print "Dataframe Types \n \n", dataframe.dtypes,"\n"
    print "Dataframe Shape \n", dataframe.shape,"\n"
    print "Dataframe Describe \n \n", dataframe.describe(include='all'),"\n"
    for feature in dataframe: 
        print feature
        print dataframe[feature].nunique()
# Out:
# /Users/yonilevine/anaconda/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df=pd.read_csv('~/Downloads/Iowa_Liquor_sales_sample_10pct.csv')
df.columns=['date','store_number','city','zip','county_number','county','category','category_name','vendor_number','item_number','item_descript','bottle_ml','state_cost','state_retail','bottles_sold','sale','volume_sold_l','volume_sold_g']

# %%
##Cleaning the data
df['state_cost'].replace('\$','',regex=True,inplace=True)
df['state_retail'].replace('\$','',regex=True,inplace=True)
df['sale'].replace('\$','',regex=True,inplace=True)

# %%
##Changing column types
df[['state_cost','state_retail','sale']] = df[['state_cost','state_retail','sale']].apply(pd.to_numeric)
df[['store_number','vendor_number','item_number',]]=df[['store_number','vendor_number','item_number']].astype(object)
df['date']= pd.to_datetime(df['date'], format="%m/%d/%Y")

# %%
##Adding in some columns that might be useful later on.
df['profit']=(df.state_retail-df.state_cost)*df.bottles_sold
df['ppb']=(df.state_retail-df.state_cost)
df['profit_margin']=(df.ppb/df.state_retail)*100

# %%
##Replacing days of week numbers with day names
df['day_of_week'] = df['date'].dt.dayofweek
days = {0:'Mon',1:'Tues',2:'Wed',3:'Thurs',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['day'] = df['day_of_week'].apply(lambda x: days[x])

# %% [markdown]
# # Explore the data
#
# Perform some exploratory statistical analysis and make some plots, such as histograms of transaction totals, bottles sold, etc.

# %%
eda(df)
# Out:
# Missing Values
#
# date                0
# store_number        0
# city                0
# zip                 0
# county_number    1077
# county           1077
# category           68
# category_name     632
# vendor_number       0
# item_number         0
# item_descript       0
# bottle_ml           0
# state_cost          0
# state_retail        0
# bottles_sold        0
# sale                0
# volume_sold_l       0
# volume_sold_g       0
# profit              0
# ppb                 0
# profit_margin       0
# day_of_week         0
# day                 0
# dtype: int64
#
# Duplicate Rows
# 35
#
# Dataframe Types
#
# date             datetime64[ns]
# store_number             object
# city                     object
# zip                      object
# county_number           float64
# county                   object
# category                float64
# category_name            object
# vendor_number            object
# item_number              object
# item_descript            object
# bottle_ml                 int64
# state_cost              float64
# state_retail            float64
# bottles_sold              int64
# sale                    float64
# volume_sold_l           float64
# volume_sold_g           float64
# profit                  float64
# ppb                     float64
# profit_margin           float64
# day_of_week               int64
# day                      object
# dtype: object
#
# Dataframe Shape
# (270955, 23)
#
# Dataframe Describe
#
#                        date  store_number        city     zip  county_number  \
# count                270955      270955.0      270955  270955  269878.000000
# unique                  274        1400.0         385     415            NaN
# top     2015-12-01 00:00:00        2633.0  DES MOINES   50010            NaN
# freq                   1555        2485.0       23724    7091            NaN
# first   2015-01-05 00:00:00           NaN         NaN     NaN            NaN
# last    2016-03-31 00:00:00           NaN         NaN     NaN            NaN
# mean                    NaN           NaN         NaN     NaN      57.231642
# std                     NaN           NaN         NaN     NaN      27.341205
# min                     NaN           NaN         NaN     NaN       1.000000
# 25%                     NaN           NaN         NaN     NaN      31.000000
# 50%                     NaN           NaN         NaN     NaN      62.000000
# 75%                     NaN           NaN         NaN     NaN      77.000000
# max                     NaN           NaN         NaN     NaN      99.000000
#
#         county      category   category_name  vendor_number  item_number  \
# count   269878  2.708870e+05          270323       270955.0     270955.0
# unique      99           NaN              71          116.0       2696.0
# top       Polk           NaN  VODKA 80 PROOF          260.0      36308.0
# freq     49102           NaN           35373        46829.0       2796.0
# first      NaN           NaN             NaN            NaN          NaN
# last       NaN           NaN             NaN            NaN          NaN
# mean       NaN  1.043888e+06             NaN            NaN          NaN
# std        NaN  5.018211e+04             NaN            NaN          NaN
# min        NaN  1.011100e+06             NaN            NaN          NaN
# 25%        NaN  1.012200e+06             NaN            NaN          NaN
# 50%        NaN  1.031200e+06             NaN            NaN          NaN
# 75%        NaN  1.062310e+06             NaN            NaN          NaN
# max        NaN  1.701100e+06             NaN            NaN          NaN
#
#          ...     state_retail   bottles_sold           sale  volume_sold_l  \
# count    ...    270955.000000  270955.000000  270955.000000  270955.000000
# unique   ...              NaN            NaN            NaN            NaN
# top      ...              NaN            NaN            NaN            NaN
# freq     ...              NaN            NaN            NaN            NaN
# first    ...              NaN            NaN            NaN            NaN
# last     ...              NaN            NaN            NaN            NaN
# mean     ...        14.675760       9.871285     128.902375       8.981351
# std      ...        10.570145      24.040912     383.027369      28.913690
# min      ...         1.340000       1.000000       1.340000       0.100000
# 25%      ...         8.270000       2.000000      30.450000       1.500000
# 50%      ...        12.270000       6.000000      70.560000       5.250000
# 75%      ...        17.880000      12.000000     135.000000      10.500000
# max      ...       637.500000    2508.000000   36392.400000    2508.000000
#
#         volume_sold_g         profit            ppb  profit_margin  \
# count   270955.000000  270955.000000  270955.000000  270955.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# first             NaN            NaN            NaN            NaN
# last              NaN            NaN            NaN            NaN
# mean         2.372830      43.097436       4.902479      33.421367
# std          7.638182     128.597325       3.523867       0.497623
# min          0.030000       0.000000       0.000000       0.000000
# 25%          0.400000      10.165000       2.760000      33.333333
# 50%          1.390000      23.520000       4.100000      33.333333
# 75%          2.770000      45.000000       5.980000      33.360258
# max        662.540000   12130.800000     212.500000      71.428571
#
#           day_of_week     day
# count   270955.000000  270955
# unique            NaN       6
# top               NaN     Wed
# freq              NaN   73129
# first             NaN     NaN
# last              NaN     NaN
# mean         1.461468     NaN
# std          1.155267     NaN
# min          0.000000     NaN
# 25%          0.000000     NaN
# 50%          1.000000     NaN
# 75%          2.000000     NaN
# max          5.000000     NaN
#
# [13 rows x 23 columns]
#
# date
# 274
# store_number
# 1400
# city
# 385
# zip
# 415
# county_number
# 99
# county
# 99
# category
# 83
# category_name
# 71
# vendor_number
# 116
# item_number
# 2696
# item_descript
# 2173
# bottle_ml
# 29
# state_cost
# 1086
# state_retail
# 1112
# bottles_sold
# 137
# sale
# 6580
# volume_sold_l
# 265
# volume_sold_g
# 261
# profit
# 5864
# ppb
# 966
# profit_margin
# 629
# day_of_week
# 6
# day
# 6

# %%
##Just checking out the 425 dollar bottle, it looks ok
df[df.state_cost==425]
df[df.item_number==995381].item_descript
# Out:
# 196351    Johnnie Walker Private Collection 2015 Fruit HA
# Name: item_descript, dtype: object

# %%
#Looks like a typo 
df[df.bottles_sold==2508]
# Out:
#             date store_number          city    zip  county_number county  \
# 34867 2015-06-15         3385  CEDAR RAPIDS  52402           57.0   Linn
#
#         category   category_name vendor_number item_number ...  state_retail  \
# 34867  1031080.0  VODKA 80 PROOF            55       35317 ...          5.96
#
#        bottles_sold      sale  volume_sold_l  volume_sold_g   profit   ppb  \
# 34867          2508  14947.68         2508.0         662.54  4990.92  1.99
#
#        profit_margin  day_of_week  day
# 34867      33.389262            0  Mon
#
# [1 rows x 23 columns]

# %%
df.drop(34867,inplace=True)

# %%
df[(df['county_number'].isnull())&(df['county'].isnull())].head()
# Out:
#           date store_number          city    zip  county_number county  \
# 135 2016-01-20         5222  CEDAR RAPIDS  52402            NaN    NaN
# 198 2016-03-02         3820    SIOUX CITY  51103            NaN    NaN
# 272 2016-03-21         4222     EVANSDALE  50707            NaN    NaN
# 290 2016-03-21         5236       ANAMOSA  52205            NaN    NaN
# 321 2016-02-23         4203       WAVERLY  50677            NaN    NaN
#
#       category            category_name vendor_number item_number  ...   \
# 135  1051010.0  AMERICAN GRAPE BRANDIES           115       53214  ...
# 198  1032080.0           IMPORTED VODKA            35       34359  ...
# 272  1062300.0             FLAVORED RUM           370       42716  ...
# 290  1081600.0          WHISKEY LIQUEUR           421       64868  ...
# 321  1051100.0         APRICOT BRANDIES           434       55084  ...
#
#     state_retail  bottles_sold    sale  volume_sold_l  volume_sold_g  profit  \
# 135         4.83            24  115.92           9.00           2.38   38.64
# 198         7.50            12   90.00           2.40           0.63   30.00
# 272        11.24             3   33.72           2.25           0.59   11.25
# 290        23.00             6  138.00          10.50           2.77   46.02
# 321         5.33            24  127.92           9.00           2.38   42.72
#
#       ppb  profit_margin  day_of_week   day
# 135  1.61      33.333333            2   Wed
# 198  2.50      33.333333            2   Wed
# 272  3.75      33.362989            0   Mon
# 290  7.67      33.347826            0   Mon
# 321  1.78      33.395872            1  Tues
#
# [5 rows x 23 columns]

# %%
##Replacing missing category number with name from the ILB website
df.loc[df.category ==1022200, 'category_name'] = 'TEQUILA'

# %%
df.drop_duplicates(inplace=True)

# %%
##creating a function to look for broken zip codes
def zip_check(col):
    x=0
    for code in col:
        if str(code).isdigit() == False:
           x+=1 
    if x == 0:
        print "no bad zip codes"
    else:
        print "check "+str(x)+" zip codes"

# %%
zip_check(df.zip)
# Out:
# check 217 zip codes

# %%
##712 is the area code for Dunlap, the proper zip code is 51529.
df.replace('712-2',51529,inplace=True)
df[df['zip']==51529].head()
# Out:
#            date  store_number    city    zip  county_number    county  \
# 259510 2016-01-25          4722  BURLINGTON  56201           29.0  Des Moines
#
#          category                     category_name  vendor_number  \
# 1871    1012100.0                 CANADIAN WHISKIES            115
# 10905   1011200.0         STRAIGHT BOURBON WHISKIES             65
# 16256   1031080.0                    VODKA 80 PROOF            301
# 38808   1031080.0                    VODKA 80 PROOF            301
# 67365   1062300.0                      FLAVORED RUM            370
# 105393  1012300.0                    IRISH WHISKIES            370
# 114370  1032080.0                    IMPORTED VODKA            370
# 130753  1011300.0                TENNESSEE WHISKIES             85
# 130844  1012100.0                 CANADIAN WHISKIES            115
# 133337  1052010.0           IMPORTED GRAPE BRANDIES            420
# 153690  1031080.0                    VODKA 80 PROOF            434
# 154766  1031080.0                    VODKA 80 PROOF            434
# 159255  1011100.0                  BLENDED WHISKIES            260
# 182807  1062310.0                        SPICED RUM            259
# 190576  1031080.0                    VODKA 80 PROOF            434
# 190804  1042100.0                 IMPORTED DRY GINS            260
# 204596  1031080.0                    VODKA 80 PROOF            434
# 215302  1022100.0                           TEQUILA             65
# 231056  1011300.0                TENNESSEE WHISKIES             85
# 238674  1081600.0                   WHISKEY LIQUEUR             85
# 247837  1062200.0  PUERTO RICO & VIRGIN ISLANDS RUM             35
# 254176  1012100.0                 CANADIAN WHISKIES            260
# 259510  1031080.0                    VODKA 80 PROOF            434
#
#         item_number ...  state_retail  bottles_sold    sale  volume_sold_l  \
# 1871          11788 ...         15.68             6   94.08           10.5
# 10905         19476 ...         25.19            12  302.28            9.0
# 16256         38176 ...         14.48            12  173.76            9.0
# 38808         38176 ...         14.48            12  173.76            9.0
# 67365         42716 ...         11.24            12  134.88            9.0
# 105393        15626 ...         21.74            12  260.88            9.0
# 114370        34006 ...         17.24            12  206.88            9.0
# 130753        86670 ...         22.61            12  271.32            9.0
# 130844        11788 ...         15.68            12  188.16           21.0
# 133337        48106 ...         28.49            12  341.88            9.0
# 153690        36305 ...          5.01            36  180.36           27.0
# 154766        36305 ...          5.01            36  180.36           27.0
# 159255        25608 ...         17.94             6  107.64           10.5
# 182807        43028 ...         17.33            12  207.96           21.0
# 190576        36308 ...         10.76             6   64.56           10.5
# 190804        28866 ...         18.75            12  225.00            9.0
# 204596        36308 ...         10.76             6   64.56           10.5
# 215302        89786 ...         14.18            12  170.16            9.0
# 231056        26826 ...         22.61            12  271.32            9.0
# 238674        86886 ...         14.78            12  177.36            9.0
# 247837        43126 ...         12.39            12  148.68            9.0
# 254176        11296 ...         22.50            12  270.00            9.0
# 259510        36305 ...          5.01            36  180.36           27.0
#
#         volume_sold_g  profit   ppb  profit_margin  day_of_week  day
# 1871             2.77   31.38  5.23      33.354592            4  Fri
# 10905            2.38  100.80  8.40      33.346566            4  Fri
# 16256            2.38   57.96  4.83      33.356354            0  Mon
# 38808            2.38   57.96  4.83      33.356354            0  Mon
# 67365            2.38   45.00  3.75      33.362989            0  Mon
# 105393           2.38   87.00  7.25      33.348666            0  Mon
# 114370           2.38   69.00  5.75      33.352668            4  Fri
# 130753           2.38   90.48  7.54      33.348076            0  Mon
# 130844           5.55   62.76  5.23      33.354592            0  Mon
# 133337           2.38  114.00  9.50      33.345033            0  Mon
# 153690           7.13   60.12  1.67      33.333333            4  Fri
# 154766           7.13   60.12  1.67      33.333333            0  Mon
# 159255           2.77   35.88  5.98      33.333333            5  Sat
# 182807           5.55   69.36  5.78      33.352568            4  Fri
# 190576           2.77   21.54  3.59      33.364312            0  Mon
# 190804           2.38   75.00  6.25      33.333333            5  Sat
# 204596           2.77   21.54  3.59      33.364312            0  Mon
# 215302           2.38   56.76  4.73      33.356841            0  Mon
# 231056           2.38   90.48  7.54      33.348076            4  Fri
# 238674           2.38   59.16  4.93      33.355886            0  Mon
# 247837           2.38   49.56  4.13      33.333333            0  Mon
# 254176           2.38   90.00  7.50      33.333333            0  Mon
# 259510           7.13   60.12  1.67      33.333333            0  Mon
#
# [23 rows x 23 columns]

# %%
##The Iowa zip codes all begin with numbers between 50 and 52 anything that began with anything above that is obviously 
# a mistake. The real zipcode is 52601
df.zip.replace(56201,52601,inplace=True)

# %%
#There doesn't seems to be any negative values for any columns were it would be a problem
print df[df['sale']<=0].shape
print df[df['bottle_ml']<0].shape
print df[df['state_cost']<=0].shape
print df[df['state_retail']<=0].shape
print df[df['bottles_sold']<=0].shape
print df[df['volume_sold_l']<=0].shape
print df[df['volume_sold_g']<=0].shape
# Out:
# (0, 23)
# (0, 23)
# (0, 23)
# (0, 23)
# (0, 23)
# (0, 23)
# (0, 23)

# %%
##Many columns are missing various values in category_name and county which are referenced elesewhere in the data-frame 

##Creating dictionaries of each category:category_name and county:county_number, and the opposite.
a=dict(zip(df.category.unique(),df.category_name.unique()))
b=dict(zip(df.category_name.unique(),df.category.unique()))
c=dict(zip(df.county_number.unique(),df.county.unique()))
d=dict(zip(df.county.unique(),df.county_number.unique()))

# %%
#Referencing any category row that is True for our mask rule, and mapping over them using the dictionaries I created as a
#guide for the reference column.
mask1 = df.category_name.isnull()
mask2 = df.category.isnull()
mask3 = df.county.isnull()
mask4 = df.county_number.isnull()
df.loc[mask1,'category_name'] = df.loc[mask1, 'category'].map(a)
df.loc[mask2,'category'] = df.loc[mask2, 'category_name'].map(b)
df.loc[mask3,'county'] = df.loc[mask3, 'county_number'].map(c)
df.loc[mask4,'county_number'] = df.loc[mask4, 'county'].map(d)

# %%
df.dropna(how='any',inplace=True)

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# store_number              int64
# city                     object
# zip                       int64
# county_number           float64
# county                   object
# category                float64
# category_name            object
# vendor_number             int64
# item_number               int64
# item_descript            object
# bottle_ml                 int64
# state_cost              float64
# state_retail            float64
# bottles_sold              int64
# sale                    float64
# volume_sold_l           float64
# volume_sold_g           float64
# profit                  float64
# ppb                     float64
# profit_margin           float64
# day_of_week               int64
# day                      object
# dtype: object

# %%
##I'm going to create a correlation heat map with all of my quantitative data to try to find  parameters to put into the model.
num_data=pd.DataFrame(df[['sale','volume_sold_l','bottles_sold','state_cost','state_retail','bottle_ml']],index=None)
num_data.head()
# Out:
#      sale  volume_sold_l  bottles_sold  state_cost  state_retail  bottle_ml
# 0   81.00            9.0            12        4.50          6.75        750
# 1   41.26            1.5             2       13.75         20.63        750
# 2  453.36           24.0            24       12.59         18.89       1000
# 3   85.50           10.5             6        9.50         14.25       1750
# 4  129.60           21.0            12        7.20         10.80       1750

# %%
data_matrix = num_data.as_matrix()

# %%
correlation_matrix = np.corrcoef(data_matrix.T)

# %%
sb.heatmap(correlation_matrix,annot = True,linewidths = 0.5)

plt.show()

# %% [markdown]
# # Record your findings
#
# Be sure to write out anything observations from your exploratory analysis.

# %%
#There seems to be a quite obvious correlation between sale amount vs. volume sold in liters, 
#and sale amount vs. bottles sold. While it may seem like a good thing that we found such a strong paramater 
#for sale amount the clear lack of independence b/w all the variables, has a negative affect on our data that must be
#accounted for, either by dropping it completely or creating an interaction terms. There is a perfect correlation b/w state cost 
# and state retail, this is because the markup is an even 33% for all categories.

# %% [markdown]
# # Mine the data
#
# Now you are ready to compute the variables you will use for your regression from the data. For example, you may want to compute total sales per store from Jan to March of 2015, mean price per bottle, etc. Refer to the readme for more ideas appropriate to your scenario.
#
# Pandas is your friend for this task. Take a look at the operations here for ideas on how to make the best use of pandas and feel free to search for blog and Stack Overflow posts to help you group data by certain variables and compute sums, means, etc. You may find it useful to create a new data frame to house this summary data.

# %%
##Placing all of the sub-data-frames that I'm working with together to remove clutter
df15=pd.DataFrame(df[df['date'].dt.year==2015])
dfq115=pd.DataFrame(df15[(df15['date'].dt.year==2015)&(df15['date'].dt.month < 4)])
dfq23415=df15[df15['date'].dt.month > 3]
salesq115=dfq115['sale'].groupby(dfq115.store_number).sum()
salesq23415=dfq23415['sale'].groupby(dfq23415.store_number).sum()
sales15=df15['sale'].groupby(df15.store_number).sum()
salesfull=pd.DataFrame(sales15)
salesfull['quarter115_sales']=salesq115
dfq116=df[df['date'].dt.year==2016]
salesq116=dfq116['sale'].groupby(df.store_number).sum()
salesq116=pd.DataFrame(salesq116)
salesfull['quarter116_sales']=salesq116

# %%
##Averages of basic stats for each store
df15stats=df15.groupby(['county','store_number']).agg({'state_retail':'mean','profit':'mean','ppb':'mean','volume_sold_l':'mean','bottles_sold':'mean','bottle_ml':'mean','sale':'sum','sale':'mean',})
df15stats
# Out:
#                         bottles_sold       ppb    bottle_ml     profit  \
# county    store_number
# Adair     3461              6.522013  4.256352  1059.276730  24.693774
#           3969             17.000000  6.332500   728.125000  58.085000
#           4317              5.795455  4.750985  1034.090909  25.042727
#           4417             12.250000  4.301250   950.000000  48.814167
#           4620              9.152174  6.303913  1222.826087  47.080435
#           4654              8.814286  4.138143   897.142857  32.737429
#           4753             15.692308  3.297692   717.307692  37.841538
#           5052             15.473684  3.473158   740.789474  40.632632
# Adams     2327              3.989418  5.099841  1008.730159  18.082910
# Allamakee 2178              8.135021  4.868861  1019.831224  34.454430
#           3857              6.675079  5.367886  1074.842271  33.276593
#           4034              9.387097  4.339355  1059.677419  31.440645
#           4289              7.302326  5.153256  1191.860465  38.394651
#           4896              7.558140  5.173953   911.046512  25.122093
#           5017              6.203390  4.137373   994.703390  22.872966
# Appanoose 2523              7.517500  4.735050   892.562500  29.617875
#           4027             10.169492  4.527373  1150.423729  43.743559
#           4046              3.824427  4.199771   885.114504  13.068244
#           4232              6.517241  6.231034  1107.758621  37.463448
#           4472               6.529063   79.000000     13.350104
# Audubon   3631               6.993421   76.795439     12.946842
#           4523              14.368421  151.035789     11.883158
#           5173               6.524655   82.843103     13.068103
# Benton    4025               5.120073   55.247007     12.816058
#           4059               2.200000   21.082000      9.038000
#           4070               8.195426  101.830266     17.343245
#           4228              13.531579  161.812924     13.207661
#           4346               2.780517   31.661218     13.414649
#           4551               9.636364  102.984091     10.027727
# ...                               ...         ...           ...
# Woodbury  4565               8.859821  106.264464     11.397857
#           4568               6.038626   90.187710     12.436183
#           4588               7.304100  130.236700     13.110600
#           4676               3.213871   53.794731     12.503656
#           4703               6.828125  126.382500     14.073750
#           4791               9.187500  166.766250     14.956250
#           4879               9.139775  127.092793     12.593063
#           4884               9.389706  115.525294     10.507353
#           4888               4.129574   74.554823     13.180213
#           4975               7.554545  130.301818     12.840909
#           5027               9.723214  212.614821     28.198393
#           5045               7.738095  104.771429     11.382698
#           5065               2.398194   37.894306     11.040417
#           5076               3.788095   77.668571     11.980952
#           5083               6.768750  106.850000     11.274583
#           5086               8.695192  123.275962      9.825769
#           5188               5.670588  111.042941     13.257059
# Worth     3664               5.715030   67.221856     13.539521
#           4839              10.800762  117.235714     14.547524
#           5115               6.203571   78.755000     10.412143
# Wright    3056               6.325269   75.910108     13.772258
#           3654              12.235075  141.482090     15.338358
#           4236              12.651316  141.765842     16.004263
#           4247               8.830000   96.146400     14.904800
#           4358              11.766129  145.779032     12.720323
#           4398              11.970000  122.453000     13.005000
#           4459               9.761207  117.114310     11.713276
#           4515              11.345455  165.572727     10.972727
#           4556              12.000000  146.605714     11.095714
#           4591               9.240000  118.512000     11.333000
#
# [1372 rows x 7 columns]

# %%
df.state_retail.mean()
# Out:
# 14.67434605758249

# %%
##this is a break down of each store contained in every city by the sum of sales for the first three months of 2015
dfq115.groupby(['county','store_number',dfq115['date'].dt.month]).agg({'sale':['sum']})
# Out:
#                                 sale
#                                  sum
# county    store_number date
# Adair     3461         1     1026.92
#                        2      197.64
#                        3      740.03
#           3969         1      427.32
#                        2      840.62
#                        3      126.00
#           4317         1      182.86
#                        2      613.31
#                        3      953.53
#           4417         2      338.52
#                        3      393.00
#           4620         1      594.34
#                        2      659.52
#                        3      442.70
#           4654         1      244.44
#                        2      580.95
#                        3      618.60
#           4753         1      467.28
#                        2      180.24
#           5052         1      345.36
#                        2      248.82
# Adams     2327         1      473.31
#                        2      537.34
#                        3     1242.95
# Allamakee 2178         1     2251.52
#                        2     1427.65
#                        3     2177.24
#           3857         1     2221.58
#                        2     1056.96
#                        3     1457.38
# ...                              ...
# Worth     3664         1     1016.91
#                        2      592.23
#                        3     1034.79
#           4839         1      655.80
#                        2      518.78
#                        3     1626.72
#           5115         3      601.02
# Wright    3056         1      832.42
#                        2      610.46
#                        3      752.66
#           3654         1      785.10
#                        2      729.92
#                        3      797.40
#           4236         1     1581.47
#                        2      897.87
#                        3     1829.18
#           4358         1      292.14
#                        2      502.08
#                        3      697.13
#           4398         1      222.12
#                        2      193.68
#                        3      630.81
#           4459         1      126.51
#                        2      193.68
#                        3      445.02
#           4515         1      268.08
#                        2      458.40
#           4556         1      350.40
#                        3      230.64
#           4591         1       81.60
#
# [3431 rows x 1 columns]

# %%
salesfull.dropna(how='any',inplace=True)

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
##The first half of the week seems busier than the second, maybe because stores want to restock before the weekend?
ts=df15.groupby('day_of_week').agg({'sale':['sum']})

ts
# Out:
#                    sale
#                     sum
# day_of_week
# 0           7762271.350
# 1           6983823.520
# 2           7210609.830
# 3           5510103.320
# 4            741644.720
# 5            272883.710

# %%
ts = df15.groupby('day_of_week').agg({'sale':['sum']})

ts.plot()

# %%
plt.show()

# %%
top500=df15.groupby(df15.store_number).sum().nlargest(500,'sale').index

# %%
topsales=df15[[store in top500 for store in df15.store_number]].groupby('store_number').agg(lambda x:x.value_counts().index[0])
topsales
# Out:
#                    date             city    zip  county_number         county  \
# store_number
# 2106         2015-03-12      CEDAR FALLS  50613          7.000     Black Hawk
# 2130         2015-08-13         WATERLOO  50703          7.000     Black Hawk
# 2178         2015-05-13           WAUKON  52172          3.000      Allamakee
# 2190         2015-11-24       DES MOINES  50314         77.000           Polk
# 2191         2015-05-22           KEOKUK  52632         56.000            Lee
# 2200         2015-02-25         SAC CITY  50583         81.000            Sac
# 2205         2015-12-28         CLARINDA  51632         73.000           Page
# 2228         2015-12-15        WINTERSET  50273         61.000        Madison
# 2233         2015-06-02      SPIRIT LAKE  51360         30.000      Dickinson
# 2238         2015-04-22          ALTOONA  50009         77.000           Polk
# 2248         2015-04-02       DES MOINES  50312         77.000           Polk
# 2285         2015-09-02        IOWA CITY  52240         52.000        Johnson
# 2290         2015-12-29       STORM LAKE  50588         11.000    Buena Vista
# 2353         2015-12-08           CRESCO  52136         45.000         Howard
# 2413         2015-03-31          DUBUQUE  52001         31.000        Dubuque
# 2448         2015-11-30        INDIANOLA  50125         91.000         Warren
# 2460         2015-12-26          HAMPTON  50441         35.000       Franklin
# 2465         2015-08-11          DUBUQUE  52003         31.000        Dubuque
# 2478         2015-11-20          ALTOONA  50009         77.000           Polk
# 2487         2015-05-11          ANAMOSA  52205         53.000          Jones
# 2500         2015-12-22             AMES  50010         85.000          Story
# 2501         2015-02-25             AMES  50010         85.000          Story
# 2502         2015-04-29           ANKENY  50021         77.000           Polk
# 2505         2015-12-02            BOONE  50036          8.000          Boone
# 2506         2015-12-26       BURLINGTON  52601         29.000     Des Moines
# 2507         2015-08-03       BURLINGTON  52601         29.000     Des Moines
# 2508         2015-12-28     CEDAR RAPIDS  52405         57.000           Linn
# 2509         2015-06-29     CEDAR RAPIDS  52404         57.000           Linn
# 2512         2015-05-18        IOWA CITY  52240         52.000        Johnson
# 2513         2015-12-22        IOWA CITY  52240         52.000        Johnson
# ...                 ...              ...    ...            ...            ...
# 5034         2015-10-29       MASON CITY  50401         17.000    Cerro Gordo
# 5043         2015-10-15         WATERLOO  50702          7.000     Black Hawk
# 2487                45888           Sailor Jerry Spiced Navy Rum  ...
# 2500                35318                           Barton Vodka  ...
# 2501                37348                           Black Velvet  ...
# 2502                22155                          Hawkeye Vodka  ...
# 2505                43120                          Hawkeye Vodka  ...
# 2506                84617           Absolut Swedish Vodka 80 Prf  ...
# 2507                36908                          Hawkeye Vodka  ...
# 2508                36908                          Hawkeye Vodka  ...
# 2509                36904  Jose Cuervo Especial Reposado Tequila  ...
# 2512                80457                           Black Velvet  ...
# 2513                48105                          Hawkeye Vodka  ...
# ...                   ...                                    ...  ...
# 5034                64858                          Hawkeye Vodka  ...
# 5043                81204                    New Amsterdam Vodka  ...
# 5050                35916                     Five O'clock Vodka  ...
# 5054                 1799                           Black Velvet  ...
# 5063                56194        Paul Masson Grande Amber Brandy  ...
# 5068                67527                     Five O'clock Vodka  ...
# 5077                43028                          Hawkeye Vodka  ...
# 5080                10549                     Five O'clock Vodka  ...
# 5100                36903                              Five Star  ...
# 5102                69638     Dr. Mcgillicuddy's Cherry Schnapps  ...
# 5105                36908                     Five O'clock Vodka  ...
# 5106                58872                            Crown Royal  ...
# 5116                36308                           Black Velvet  ...
# 5121                35926                     Five O'clock Vodka  ...
# 5123                37996                   Bacardi Superior Rum  ...
# 5124                36978                          Nikolai Vodka  ...
# 5125                31658                          Hawkeye Vodka  ...
# 5126                36886                          Hawkeye Vodka  ...
# 5127                36978                          Nikolai Vodka  ...
# 5128                64858                             Skol Vodka  ...
# 5129                23828                    Paramount White Rum  ...
# 5131                11290                            Hennessy VS  ...
# 5140                12407                    Canadian Ltd Whisky  ...
# 5144                45278                    Paramount White Rum  ...
# 5145                48099                            Hennessy VS  ...
# 5146                11776                           Black Velvet  ...
# 5151                11788                           Black Velvet  ...
# 5172                36904        Paul Masson Grande Amber Brandy  ...
# 9001                27014                 Cedar Ridge Malted Rye  ...
# 9002                27027                          Cody Road Rye  ...
#
#               state_retail  bottles_sold    sale  volume_sold_l  \
# store_number
# 2106                11.430            12 137.160         12.000
# 2130                11.430            12 137.160         12.000
# 2178                27.000            12 162.000          0.750
# 2190                12.380             2  30.000          1.500
# 2191                11.430            12 137.160         12.000
# 2200                13.500             2  45.000          1.500
# 2205                27.750             2 333.000          1.500
# 2228                12.380             1  12.380          0.750
# 2233                 9.950            12  90.000         10.500
# 2238                17.240            12 221.400          9.000
# 2248                15.000             6  90.000          9.000
# 2285                12.380            12 148.560          9.000
# 2290                15.000             2  45.000          1.500
# 2353                15.000             2  30.000          1.500
# 2413                22.490            12 144.000         12.000
# 2448                 9.750             1  22.500          0.750
# 2460                15.000            12  73.800         10.500
# 2465                12.380             2 162.000          1.500
# 2478                 5.960            12 226.680         12.000
# 2487                11.430             2 102.000          1.500
# 2500                12.380            12 148.560          9.000
# 2501                12.380            12 148.560          9.000
# 2502                12.380            12 117.000          9.000
# 2505                11.430            12 137.160          9.000
# 2506                12.380            12 126.000          9.000
# 2507                 9.750            12  70.560          9.000
# 2508                15.000            12 124.200          9.000
# 2509                12.380            12 162.000          9.000
# 2513                  2.380  10.500  3.250         33.333            2    Wed
# ...                     ...     ...    ...            ...          ...    ...
# 5034                  2.380  27.360 14.860         33.333            3  Thurs
# 5043                  2.380  23.520  0.980         33.333            3  Thurs
# 5050                  2.380  20.280  3.250         33.333            2    Wed
# 5054                  2.380  57.000  4.750         33.333            0    Mon
# 5063                  2.380   2.640  0.980         33.333            3  Thurs
# 5068                  0.400  10.000  5.000         33.333            1   Tues
# 5077                  2.380  49.560  4.130         33.333            0    Mon
# 5080                  2.770  35.600  3.560         33.333            1   Tues
# 5100                  2.380  38.640  1.610         33.333            0    Mon
# 5102                  3.170  45.720  3.810         33.333            3  Thurs
# 5105                  2.380  22.440  7.500         33.333            2    Wed
# 5106                  2.380  26.040  2.170         33.333            3  Thurs
# 5116                  0.400  31.380  3.150         33.333            3  Thurs
# 5121                  2.380   3.710  5.000         33.333            1   Tues
# 5123                  2.380  49.560  4.130         33.333            0    Mon
# 5124                  2.380  49.560  4.130         33.333            1   Tues
# 5125                  2.380  39.000  3.250         33.333            3  Thurs
# 5126                  2.380  19.500  3.250         33.333            1   Tues
# 5127                  2.380  49.560  5.000         33.333            3  Thurs
# 5128                  2.380  49.560  4.130         33.333            0    Mon
# 5129                  2.380  31.500  5.250         33.333            3  Thurs
# 5131                  2.380  60.000  5.000         33.333            2    Wed
# 5140                  3.170  66.000  2.750         33.333            1   Tues
# 5144                  3.170 114.000  3.920         33.333            3  Thurs
# 5145                  2.380  67.920  1.750         33.333            2    Wed
# 5146                  2.770  31.440  3.450         33.333            3  Thurs
# 5151                  2.380  90.000  5.230         33.333            2    Wed
# 5172                  0.590  15.000  4.130         33.333            2    Wed
# 9001                  2.380 177.120  9.840         33.333            2    Wed
# 9002                  2.380 109.200  4.550         33.358            3  Thurs
#
# [500 rows x 22 columns]

# %%
plt.hist(df15['bottles_sold'],bins=20,range=(0,100))
plt.show()

# %% [markdown]
# # Refine the data
#
# Look for any statistical relationships, correlations, or other relevant properties of the dataset.

# %%
# category_dummy=pd.get_dummies(topsales['day_of_week']

# %%
# topsales_dummy['summed_sales']=df15.groupby('store_number').agg({'sale':'sum'}).nlargest(500,'sale')
# topsales_dummy.isnull().sum()
# X3 = topsales_dummy[]

# y3 = topsales_dummy['summed_sales']

# model1 = sm.OLS(y3, X3).fit() 
# predictions_dummy = model.predict(X3)
# model1.summary()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = salesfull['quarter115_sales']
y = salesfull['sale']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit() 
predictions15 = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   sale   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                 3.339e+04
# Date:                Wed, 15 Nov 2017   Prob (F-statistic):               0.00
# Time:                        15:46:36   Log-Likelihood:                -12500.
# No. Observations:                1176   AIC:                         2.500e+04
# Df Residuals:                    1174   BIC:                         2.501e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const              752.7925    316.825      2.376      0.018     131.186    1374.400
# quarter115_sales     4.4650      0.024    182.725      0.000       4.417       4.513
# ==============================================================================
# Omnibus:                      647.574   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39828.189
# Skew:                           1.744   Prob(JB):                         0.00
# Kurtosis:                      31.296   Cond. No.                     1.41e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X
# Out:
#               const  quarter115_sales
# store_number
# 2106          1.000         39287.290
# 2113          1.000          2833.250
# 2130          1.000         24272.570
# 2152          1.000          2003.460
# 2178          1.000          5856.410
# 2190          1.000         29249.400
# 2191          1.000         29085.570
# 2200          1.000          4900.430
# 2228          1.000          5193.970
# 2233          1.000          5374.550
# 2238          1.000           858.610
# 2248          1.000         12663.680
# 2285          1.000         10019.120
# 2290          1.000         12191.260
# 2327          1.000          2253.600
# 2353          1.000         17382.600
# 2413          1.000         22459.160
# 2445          1.000          1215.080
# 2448          1.000          5655.920
# 2459          1.000          1609.570
# 2465          1.000          5615.990
# 2475          1.000          5672.760
# 2478          1.000          4459.850
# 2498          1.000           279.220
# 2500          1.000         40234.900
# 2501          1.000         31412.950
# 2502          1.000         39420.060
# 2505          1.000         14559.280
# 2506          1.000         31009.770
# 2507          1.000          8344.010
# ...             ...               ...
# 5083          1.000            74.400
# 5086          1.000           810.600
# 5088          1.000           479.160
# 5089          1.000           884.030
# 5090          1.000          2193.890
# 5091          1.000           523.820
# 5092          1.000          1815.540
# 5094          1.000           511.860
# 5096          1.000          2040.420
# 5097          1.000          3160.020
# 5098          1.000          1360.740
# 5099          1.000          1250.490
# 5100          1.000          2180.760
# 5101          1.000          1701.470
# 5102          1.000         27695.760
# 5103          1.000            42.760
# 5104          1.000          1555.830
# 5105          1.000          2708.560
# 5106          1.000          2691.840
# 5108          1.000           999.950
# 5112          1.000           803.560
# 5113          1.000          2427.840
# 5114          1.000           406.020
# 5115          1.000           601.020
# 5116          1.000          1406.570
# 5119          1.000           112.500
# 5128          1.000           477.000
# 9001          1.000          2341.080
# 9002          1.000          4865.160
# 9010          1.000          3861.600
#
# [1176 rows x 2 columns]

# %%
model = sm.OLS(y, X).fit()
X2=salesfull['quarter116_sales']
X2=sm.add_constant(X2)
salesfull['quarter23416']=model.predict(X2)

# %%
salesfull['full_2016']=salesfull['quarter23416']

# %%
salesfull.head()
print salesfull.sale.sum()
print salesfull.full_2016.sum()
# Out:
# 27356568.5
# 27861560.4712

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=9245)

# %%
linreg = LinearRegression(normalize=True)
linreg.fit(X_train, y_train)
# Out:
# /Users/yonilevine/anaconda/lib/python2.7/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
y_pred1 = linreg.predict(X_test)
print np.sqrt(metrics.mean_squared_error(y_test, y_pred1))
# Out:
# 9043.97872077

# %%
ridgereg = Ridge(alpha=.1)
ridgereg.fit(X_train, y_train)
y_pred2 = ridgereg.predict(X_test)
print np.sqrt(metrics.mean_squared_error(y_test, y_pred1))
# Out:
# 9043.97872077

# %%
plt.scatter(predictions15, y, s=30, c='b', marker='+', zorder=10)
plt.xlabel("Predicted Values from Q1")
plt.ylabel("Actual Values 2015")
plt.show()
print "MSE:", model.mse_model
# Out:
# MSE: 3.34548729818e+12

# %%
(275784905.11-273425332.18)/273425332.18*100
# Out:
# 0.8629679302891602
